# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path
from pprint import pp

from dotenv import dotenv_values

# %%
from digital_design_dataset.dataset.design_dataset import DesignDataset
from digital_design_dataset.flows.design_hierarchy import extract_design_hierarchy

# %%
current_script_dir = Path("demo_scripts")
test_db_dir = current_script_dir / "test_dataset_v2"
d = DesignDataset(test_db_dir, overwrite=False)

# %%
test_design = d.get_design_metadata("RC5")
assert test_design is not None

test_design_sources = d.get_design_source_files(test_design["design_name"])
print(test_design["design_name"])
pp(test_design_sources)
# Out:
# RC5
# [Path('demo_scripts/test_dataset_v2/designs/RC5/sources/topModule.v')]

# %%
extract_design_hierarchy(test_design_sources)
# Out:
# ['rc5', 'rc5_dpc', 'rc5_keyex', 'rc5_rol', 'top']
# [
# │   {
# │   │   'name': 'rc5',
# │   │   'cell_sorts': [
# │   │   │   {
# │   │   │   │   'type': 'rc5_keyex',
# │   │   │   │   'ports': [
# │   │   │   │   │   {'name': 'i_clk', 'direction': 'io', 'range': [0, 0]},
# │   │   │   │   │   {'name': 'i_key', 'direction': 'io', 'range': [128, 0]},
# │   │   │   │   │   {'name': 'i_key_en', 'direction': 'io', 'range': [0, 0]},
# │   │   │   │   │   {'name': 'i_rst', 'direction': 'io', 'range': [0, 0]},
# │   │   │   │   │   {'name': 'o_exkey', 'direction': '', 'range': [832, 0]},
# │   │   │   │   │   {'name': 'o_key_ok', 'direction': '', 'range': [0, 0]}
# │   │   │   │   ],
# │   │   │   │   'cells': [
# │   │   │   │   │   {
# │   │   │   │   │   │   'name': 'u_keyex',
# │   │   │   │   │   │   'connections': [
# │   │   │   │   │   │   │   {'name': 'i_clk', 'signals': [{'width': '1', 'type': 'wire', 'const': False}]},
# ...
